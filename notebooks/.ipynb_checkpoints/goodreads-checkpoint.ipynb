# %% [markdown]
# <h1>Goodreads</h1>

# %%
import pandas as pd
import requests
import xmltodict
from datetime import datetime
from collections import Counter
import matplotlib.pyplot as plt

# %%
to_read_books_url = 'https://www.goodreads.com/review/list/' + user_id + '.xml?key=Ps9P2LhtrqgsfwEEA0iUA&v=2&shelf=to-read&per_page=200'
fallback_url = 'https://www.goodreads.com/review/list/52479819.xml?key=Ps9P2LhtrqgsfwEEA0iUA&v=2&shelf=to-read&per_page=200'
fallback_url_page2 = 'https://www.goodreads.com/review/list/52479819.xml?key=Ps9P2LhtrqgsfwEEA0iUA&v=2&shelf=to-read&per_page=200&page=2'
# need to add this because not all of 2019's books are in the first call (max 200 items)

# %%
to_read_request = requests.get(fallback_url)
to_read_request_2 = requests.get(fallback_url_page2)

# %%
to_read = xmltodict.parse(to_read_request.content)
to_read_2 = xmltodict.parse(to_read_request_2.content)

# %%
books = to_read['GoodreadsResponse']['reviews']['review']
books_2 = to_read_2['GoodreadsResponse']['reviews']['review']
all_books = books + books_2
len(all_books)
# yay all books are there
# Out:
# 235

# %%
books[1]['date_added']
# Out:
# 'Sat Jan 04 10:23:57 -0800 2020'

# %%
'2019' in 'Sat Jan 04 10:23:57 -0800 2020'
# Out:
# False

# %%
to_read_2019 = []
for book in all_books:
    print(book['book']['title'])
    print('date book added: ' + str(book['date_added']))
    if '2019' in book['date_added']:
        to_read_2019.append(book)
    else:
        print("book was not added in 2019")
    print()
# Out:
# Prozac Nation
# date book added: Tue Jan 07 08:52:19 -0800 2020
# book was not added in 2019
#
# The Sellout
# date book added: Sat Jan 04 10:23:57 -0800 2020
# book was not added in 2019
#
# Sum: Forty Tales from the Afterlives
# date book added: Sat Dec 28 00:37:56 -0800 2019
#
# The Age of Surveillance Capitalism: The Fight for a Human Future at the New Frontier of Power
# date book added: Wed Dec 18 11:07:24 -0800 2019
#
# Municipal Dreams: The Rise and Fall of Council Housing
# date book added: Wed Dec 18 11:06:20 -0800 2019
#
# The Bug
# date book added: Fri Dec 13 08:50:36 -0800 2019
#
# Quiet: The Power of Introverts in a World That Can't Stop Talking
# date book added: Tue Dec 10 20:02:59 -0800 2019
#
# Rethinking Camelot: Jfk, the Vietnam War, and U.S. Political Culture
# date book added: Tue Dec 03 07:44:47 -0800 2019
#
# Debt: The First 5,000 Years
# date book added: Tue Dec 03 06:39:51 -0800 2019
#
# The Utopia of Rules: On Technology, Stupidity, and the Secret Joys of Bureaucracy
# date book added: Tue Dec 03 06:38:50 -0800 2019
#
# Horizon
# date book added: Tue Dec 03 06:00:26 -0800 2019
#
# Where Reasons End
# date book added: Tue Dec 03 05:59:34 -0800 2019
#
# In Pain: A Bioethicist's Personal Struggle with Opioids
# date book added: Tue Dec 03 05:58:56 -0800 2019
#
# The Art of Statistics: How to Learn from Data
# date book added: Tue Dec 03 05:58:29 -0800 2019
#
# The Trial
# date book added: Tue Dec 03 05:55:27 -0800 2019
#
# The Sentence is Death (Hawthorne, #2)
# date book added: Tue Dec 03 05:40:24 -0800 2019
#
# The Word Is Murder (Hawthorne, #1)
# date book added: Tue Dec 03 05:40:16 -0800 2019
#
# I Heard You Paint Houses: Frank the Irishman Sheeran & Closing the Case on Jimmy Hoffa
# date book added: Sat Nov 30 08:14:09 -0800 2019
#
# With Winning in Mind: The Mental Management System: An Olympic Champion's Success System
# date book added: Thu Nov 28 09:23:05 -0800 2019
#
# This Could Be Our Future: A Manifesto for a More Generous World
# date book added: Wed Nov 27 09:24:52 -0800 2019
#
# The Invisibles
# date book added: Wed Nov 27 07:48:37 -0800 2019
#
# The Arrival
# date book added: Fri Nov 22 00:36:35 -0800 2019
#
# Biosemiotics: The Semiotic Web 1991
# date book added: Wed Nov 20 07:12:16 -0800 2019
#
# The Ecological Approach to Visual Perception
# date book added: Wed Nov 20 07:06:34 -0800 2019
#
# Fully Automated Luxury Communism: A Manifesto
# date book added: Wed Nov 20 06:35:19 -0800 2019
#
# Daemon (Daemon, #1)
# date book added: Wed Nov 20 00:10:10 -0800 2019
#
# Open Veins of Latin America: Five Centuries of the Pillage of a Continent
# date book added: Tue Nov 12 20:53:54 -0800 2019
#
# Machine Dreams: Economics Becomes a Cyborg Science
# date book added: Mon Nov 11 21:44:44 -0800 2019
#
# Designing Data-Intensive Applications: The Big Ideas Behind Reliable, Scalable, and Maintainable Systems
# date book added: Mon Nov 11 05:35:30 -0800 2019
#
# Thoughtful Interaction Design: A Design Perspective on Information Technology
# date book added: Thu Nov 07 21:12:42 -0800 2019
#
# Atomic Habits: An Easy & Proven Way to Build Good Habits & Break Bad Ones
# date book added: Tue Nov 05 07:15:37 -0800 2019
#
# Rare Earth
# date book added: Tue Oct 29 06:37:57 -0700 2019
#
# It's Not OK to Feel Blue
# date book added: Sun Oct 13 07:19:46 -0700 2019
#
# Every Tool's a Hammer: Life Is What You Make It
# date book added: Wed Oct 09 09:02:57 -0700 2019
#
# Das Kapital
# date book added: Tue Oct 01 11:04:35 -0700 2019
#
# Legacy of Ashes: The History of the CIA
# date book added: Sun Sep 15 08:48:12 -0700 2019
#
# The Language of Cities
# date book added: Thu Sep 12 00:53:02 -0700 2019
#
# Radical Technologies: The Design of Everyday Life
# date book added: Mon Sep 09 00:19:57 -0700 2019
#
# Toppamono: Outlaw. Radical. Suspect. My Life in Japan's Underworld
# date book added: Thu Aug 29 01:48:29 -0700 2019
#
# Super Pumped: The Battle for Uber
# date book added: Tue Aug 27 20:36:30 -0700 2019
#
# Measuring the User Experience: Collecting, Analyzing, and Presenting Usability Metrics
# date book added: Tue Aug 27 08:49:27 -0700 2019
#
# Why Nations Fail: The Origins of Power, Prosperity, and Poverty
# date book added: Sat Aug 24 11:55:56 -0700 2019
#
# Sourdough
# date book added: Mon Aug 12 06:23:53 -0700 2019
#
# Lonesome Dove
# date book added: Sun Aug 11 05:19:21 -0700 2019
#
# Solaris
# date book added: Sun Aug 11 05:16:39 -0700 2019
#
# A Gentleman in Moscow
# date book added: Sun Aug 11 05:15:49 -0700 2019
#
# The Franklin Cover-Up: Child Abuse, Satanism, and Murder in Nebraska
# date book added: Sat Aug 10 07:39:50 -0700 2019
#
# Actual Air
# date book added: Thu Aug 08 02:21:03 -0700 2019
#
# Layout for Graphic Designers: An Introduction
# date book added: Wed Aug 07 01:03:43 -0700 2019
#
# Antifragile: Things That Gain from Disorder
# date book added: Tue Aug 06 08:38:47 -0700 2019
#
# Heart of Darkness
# date book added: Thu Aug 01 09:01:07 -0700 2019
#
# William Gibson's Alien 3
# date book added: Wed Jul 31 10:17:24 -0700 2019
#
# The Responsible Company: What We've Learned from Patagonia's First 40 Years
# date book added: Tue Jul 23 20:02:06 -0700 2019
#
# The Library of Babel
# date book added: Sun Jul 21 08:39:31 -0700 2019
#
# Earth
# date book added: Sun Jul 21 08:24:34 -0700 2019
#
# A New Kind of Science
# date book added: Sun Jul 21 07:31:58 -0700 2019
#
# Originals: How Non-Conformists Move the World
# date book added: Tue Jul 16 02:42:05 -0700 2019
#
# The Bitcoin Standard: The Decentralized Alternative to Central Banking
# date book added: Thu Jul 11 20:06:13 -0700 2019
#
# Red Harvest
# date book added: Sun Jun 30 03:43:32 -0700 2019
#
# Trick Mirror: Reflections on Self-Delusion
# date book added: Wed Jun 26 08:22:42 -0700 2019
#
# On Earth We're Briefly Gorgeous
# date book added: Wed Jun 26 08:21:25 -0700 2019
#
# Sleepless Nights
# date book added: Wed Jun 26 08:15:23 -0700 2019
#
# Ruined by Design: How Designers Destroyed the World, and What We Can Do to Fix It
# date book added: Thu Jun 20 04:01:25 -0700 2019
#
# Songs of Blood and Sword: A Daughter's Memoir
# date book added: Sat Jun 15 02:38:42 -0700 2019
#
# A Brief History of Everyone Who Ever Lived: The Stories in Our Genes
# date book added: Wed Jun 05 05:55:23 -0700 2019
#
# Remediation: Understanding New Media
# date book added: Sun Jun 02 10:35:06 -0700 2019
#
# Hyperobjects: Philosophy and Ecology after the End of the World
# date book added: Sat May 25 08:20:31 -0700 2019
#
# Walkaway
# date book added: Sat May 25 08:11:49 -0700 2019
#
# Exhalation: Stories
# date book added: Mon May 20 09:44:17 -0700 2019
#
# Visual Intelligence: How We Create What We See
# date book added: Fri May 17 05:21:30 -0700 2019
#
# How to Live: A Life of Montaigne in One Question and Twenty Attempts at An Answer
# date book added: Thu May 16 09:07:48 -0700 2019
#
# October: The Story of the Russian Revolution
# date book added: Mon May 13 03:28:12 -0700 2019
#
# Ajax, the Dutch, the War: Football in Europe During the Second World War
# date book added: Wed May 08 04:57:40 -0700 2019
#
# The Futurological Congress: From the Memoirs of Ijon Tichy
# date book added: Thu May 02 09:20:03 -0700 2019
#
# The Essential Writings of Ralph Waldo Emerson
# date book added: Tue Apr 30 09:40:53 -0700 2019
#
# Delete: The Virtue of Forgetting in the Digital Age
# date book added: Sat Apr 27 09:22:50 -0700 2019
#
# The Infinity of Lists
# date book added: Sat Apr 27 09:22:29 -0700 2019
#
# Cruel Optimism
# date book added: Sat Apr 27 09:21:42 -0700 2019
#
# Simulacra and Simulation
# date book added: Sat Apr 27 09:21:18 -0700 2019
#
# The System of Objects
# date book added: Sat Apr 27 09:21:04 -0700 2019
#
# Radical Candor: Be a Kickass Boss Without Losing Your Humanity
# date book added: Thu Apr 25 23:22:02 -0700 2019
#
# Gore Vidal: History of The National Security State
# date book added: Thu Apr 11 09:05:05 -0700 2019
#
# Wabi-Sabi: For Artists, Designers, Poets & Philosophers
# date book added: Wed Apr 10 09:24:33 -0700 2019
#
# Calm Technology: Designing for Billions of Devices and the Internet of Things
# date book added: Fri Apr 05 07:51:03 -0700 2019
#
# Moralizing Technology: Understanding and Designing the Morality of Things
# date book added: Fri Apr 05 07:49:40 -0700 2019
#
# Future Ethics
# date book added: Fri Apr 05 07:49:03 -0700 2019
#
# Design Is a Job
# date book added: Wed Apr 03 09:40:56 -0700 2019
#
# The Three-Body Problem (Remembrance of Earth’s Past #1)
# date book added: Sat Mar 16 08:41:44 -0700 2019
#
# Automating Inequality: How High-Tech Tools Profile, Police, and Punish the Poor
# date book added: Mon Mar 11 22:50:05 -0700 2019
#
# Information Doesn't Want to Be Free: Laws for the Internet Age
# date book added: Sun Mar 10 08:34:33 -0700 2019
#
# Americanah
# date book added: Wed Feb 27 21:48:07 -0800 2019
#
# the order of time-
# date book added: Tue Feb 12 11:36:30 -0800 2019
#
# Sons of the Profits: There's No Business Like Grow Business. The Seattle Story, 1851-1901
# date book added: Mon Feb 11 17:16:05 -0800 2019
#
# Arthur Erickson: An Architect's Life
# date book added: Thu Feb 07 11:36:21 -0800 2019
#
# The Phoenix Project: A Novel About IT, DevOps, and Helping Your Business Win
# date book added: Sat Jan 26 00:35:49 -0800 2019
#
# Convenience Store Woman
# date book added: Mon Jan 21 07:14:55 -0800 2019
#
# Walead Beshty
# date book added: Sun Jan 20 03:34:24 -0800 2019
#
# Crashed: How a Decade of Financial Crises Changed the World
# date book added: Sat Jan 19 06:04:10 -0800 2019
#
# Patriot Number One: American Dreams in Chinatown
# date book added: Sat Jan 19 05:58:02 -0800 2019
#
# The Spy and the Traitor: The Greatest Espionage Story of the Cold War
# date book added: Sun Jan 13 05:13:30 -0800 2019
#
# Seasonal Associate
# date book added: Fri Jan 11 05:44:57 -0800 2019
#
# Counterproductive: Time Management in the Knowledge Economy
# date book added: Tue Jan 01 22:13:13 -0800 2019
#
# How to Build a Car: The Autobiography of the World’s Greatest Formula 1 Designer
# date book added: Thu Dec 27 07:14:13 -0800 2018
# book was not added in 2019
#
# Oliver Byrne: The First Six Books of the Elements of Euclid
# date book added: Mon Dec 17 07:27:14 -0800 2018
# book was not added in 2019
#
# Head First Statistics
# date book added: Wed Dec 12 19:47:40 -0800 2018
# book was not added in 2019
#
# Between the World and Me
# date book added: Thu Nov 22 07:16:40 -0800 2018
# book was not added in 2019
#
# Nudge: Improving Decisions About Health, Wealth, and Happiness
# date book added: Wed Nov 21 15:49:57 -0800 2018
# book was not added in 2019
#
# Blueprint: How DNA Makes Us Who We Are
# date book added: Fri Nov 16 07:40:03 -0800 2018
# book was not added in 2019
#
# Against Creativity
# date book added: Thu Nov 15 08:26:09 -0800 2018
# book was not added in 2019
#
# The Beautiful Struggle: A Father, Two Sons and an Unlikely Road to Manhood
# date book added: Thu Nov 15 07:23:52 -0800 2018
# book was not added in 2019
#
# King, Warrior, Magician, Lover: Rediscovering the Archetypes of the Mature Masculine
# date book added: Thu Nov 15 06:54:57 -0800 2018
# book was not added in 2019
#
# Flow: The Psychology of Optimal Experience
# date book added: Sat Nov 03 01:39:09 -0700 2018
# book was not added in 2019
#
# New Dark Age: Technology and the End of the Future
# date book added: Sun Oct 21 23:58:57 -0700 2018
# book was not added in 2019
#
# Lolita
# date book added: Sun Oct 21 07:49:12 -0700 2018
# book was not added in 2019
#
# Pale Fire
# date book added: Sun Oct 21 07:48:59 -0700 2018
# book was not added in 2019
#
# The Great Good Place: Cafes, Coffee Shops, Bookstores, Bars, Hair Salons, and Other Hangouts at the Heart of a Community
# date book added: Sun Oct 21 07:43:55 -0700 2018
# book was not added in 2019
#
# Wild at Heart Revised and Updated: Discovering the Secret of a Man's Soul
# date book added: Sun Oct 21 06:42:39 -0700 2018
# book was not added in 2019
#
# The Righteous Mind: Why Good People Are Divided by Politics and Religion
# date book added: Thu Oct 18 04:17:48 -0700 2018
# book was not added in 2019
#
# Cybernetic Serendipity: Computer And The Arts
# date book added: Thu Oct 18 01:59:18 -0700 2018
# book was not added in 2019
#
# Daily Rituals: How Artists Work
# date book added: Mon Oct 15 08:48:18 -0700 2018
# book was not added in 2019
#
# The Sympathizer
# date book added: Sat Oct 13 09:15:23 -0700 2018
# book was not added in 2019
#
# The Attention Merchants: The Epic Scramble to Get Inside Our Heads
# date book added: Thu Oct 11 00:12:59 -0700 2018
# book was not added in 2019
#
# Draplin Design Co.: Pretty Much Everything
# date book added: Thu Oct 11 00:10:07 -0700 2018
# book was not added in 2019
#
# Public Domain: Edition Digital Culture 3
# date book added: Wed Oct 10 04:53:53 -0700 2018
# book was not added in 2019
#
# Machines and Robots: Edition Digital Culture 5
# date book added: Wed Oct 10 04:53:50 -0700 2018
# book was not added in 2019
#
# Attached: The New Science of Adult Attachment and How It Can Help You Find—and Keep—Love
# date book added: Mon Oct 01 08:20:29 -0700 2018
# book was not added in 2019
#
# Sapiens: A Brief History of Humankind
# date book added: Thu Sep 27 08:29:41 -0700 2018
# book was not added in 2019
#
# The Wages of Destruction: The Making and Breaking of the Nazi Economy
# date book added: Thu Sep 27 08:21:28 -0700 2018
# book was not added in 2019
#
# The White War: Life and Death on the Italian Front 1915 - 1919
# date book added: Wed Sep 26 20:44:05 -0700 2018
# book was not added in 2019
#
# Pure War
# date book added: Mon Sep 24 08:56:08 -0700 2018
# book was not added in 2019
#
# Theory of Colours
# date book added: Mon Sep 24 08:47:32 -0700 2018
# book was not added in 2019
#
# The Diamond Age: Or, A Young Lady's Illustrated Primer
# date book added: Tue Sep 18 10:13:27 -0700 2018
# book was not added in 2019
#
# The White Steamship
# date book added: Thu Sep 06 20:16:59 -0700 2018
# book was not added in 2019
#
# Don't Make Me Think, Revisited: A Common Sense Approach to Web Usability
# date book added: Mon Sep 03 09:26:15 -0700 2018
# book was not added in 2019
#
# Information Architecture: Blueprints for the Web
# date book added: Mon Sep 03 09:22:15 -0700 2018
# book was not added in 2019
#
# Cyberpunk: Stories of Hardware, Software, Wetware, Evolution, and Revolution
# date book added: Wed Aug 29 06:28:48 -0700 2018
# book was not added in 2019
#
# Death in Midsummer and Other Stories
# date book added: Tue Aug 28 09:16:56 -0700 2018
# book was not added in 2019
#
# The Third Plate: Field Notes on the Future of Food
# date book added: Mon Aug 27 07:25:52 -0700 2018
# book was not added in 2019
#
# Design as Art
# date book added: Sun Aug 26 01:55:52 -0700 2018
# book was not added in 2019
#
# The Pocket Universal Principles of Design: 150 Essential Tools for Architects, Artists, Designers, Developers, Engineers, Inventors, and Makers
# date book added: Sun Aug 26 01:52:53 -0700 2018
# book was not added in 2019
#
# Invisible Monsters
# date book added: Thu Aug 23 05:25:12 -0700 2018
# book was not added in 2019
#
# Choke
# date book added: Thu Aug 23 05:24:08 -0700 2018
# book was not added in 2019
#
# The Black Swan: The Impact of the Highly Improbable
# date book added: Mon Aug 20 03:57:55 -0700 2018
# book was not added in 2019
#
# Fooled by Randomness: The Hidden Role of Chance in Life and in the Markets
# date book added: Mon Aug 20 03:57:47 -0700 2018
# book was not added in 2019
#
# A Random Walk Down Wall Street
# date book added: Mon Aug 20 03:57:17 -0700 2018
# book was not added in 2019
#
# The Desert War Trilogy
# date book added: Thu Aug 16 00:25:07 -0700 2018
# book was not added in 2019
#
# Annihilation (Southern Reach, #1)
# date book added: Thu Aug 16 00:18:37 -0700 2018
# book was not added in 2019
#
# The Forever War (The Forever War, #1)
# date book added: Thu Aug 16 00:10:38 -0700 2018
# book was not added in 2019
#
# Mostly Harmless Econometrics: An Empiricist's Companion
# date book added: Tue Aug 07 21:08:01 -0700 2018
# book was not added in 2019
#
# The Visual Display of Quantitative Information
# date book added: Tue Aug 07 21:06:11 -0700 2018
# book was not added in 2019
#
# The Functional Art: An Introduction to Information Graphics and Visualization
# date book added: Tue Aug 07 21:05:48 -0700 2018
# book was not added in 2019
#
# Oryx and Crake (MaddAddam, #1)
# date book added: Tue Aug 07 07:23:15 -0700 2018
# book was not added in 2019
#
# Ninety-two in the Shade
# date book added: Fri Jul 27 04:56:49 -0700 2018
# book was not added in 2019
#
# Legends of the Fall
# date book added: Fri Jul 27 04:55:23 -0700 2018
# book was not added in 2019
#
# When Gravity Fails
# date book added: Wed Jul 25 09:11:29 -0700 2018
# book was not added in 2019
#
# Snow Crash
# date book added: Wed Jul 25 09:09:22 -0700 2018
# book was not added in 2019
#
# Zen in the Art of Archery
# date book added: Sun Jul 22 08:43:08 -0700 2018
# book was not added in 2019
#
# The Wind-Up Bird Chronicle
# date book added: Sun Jul 15 04:57:03 -0700 2018
# book was not added in 2019
#
# The Artist's Way
# date book added: Sun Jul 01 08:16:05 -0700 2018
# book was not added in 2019
#
# Pattern Recognition (Blue Ant, #1)
# date book added: Thu Jun 28 06:29:47 -0700 2018
# book was not added in 2019
#
# The Long Walk
# date book added: Thu Jun 28 06:26:48 -0700 2018
# book was not added in 2019
#
# In the Penal Colony
# date book added: Tue Jun 19 10:03:22 -0700 2018
# book was not added in 2019
#
# Chemistry
# date book added: Sat Jun 16 10:44:01 -0700 2018
# book was not added in 2019
#
# A People's History of the United States
# date book added: Fri Jun 15 09:56:00 -0700 2018
# book was not added in 2019
#
# Roadside Picnic
# date book added: Wed May 16 00:42:29 -0700 2018
# book was not added in 2019
#
# Compulsory Games
# date book added: Mon May 07 06:00:27 -0700 2018
# book was not added in 2019
#
# Freakonomics: A Rogue Economist Explores the Hidden Side of Everything
# date book added: Sun Apr 29 08:51:58 -0700 2018
# book was not added in 2019
#
# The Shape of Design
# date book added: Sun Apr 29 08:27:29 -0700 2018
# book was not added in 2019
#
# Invisible Cities
# date book added: Mon Apr 23 00:06:23 -0700 2018
# book was not added in 2019
#
# Metaphors We Live By
# date book added: Thu Apr 19 08:38:45 -0700 2018
# book was not added in 2019
#
# Asymmetry
# date book added: Thu Apr 19 03:49:31 -0700 2018
# book was not added in 2019
#
# Deadeye Dick
# date book added: Thu Apr 19 00:43:01 -0700 2018
# book was not added in 2019
#
# How to Win Friends and Influence People
# date book added: Mon Apr 16 10:17:58 -0700 2018
# book was not added in 2019
#
# Siddhartha
# date book added: Mon Apr 16 10:13:25 -0700 2018
# book was not added in 2019
#
# Meditations
# date book added: Mon Apr 16 10:11:25 -0700 2018
# book was not added in 2019
#
# In Praise of Shadows
# date book added: Mon Apr 16 00:32:30 -0700 2018
# book was not added in 2019
#
# The Industries of the Future
# date book added: Mon Mar 26 03:30:11 -0700 2018
# book was not added in 2019
#
# Mark Twain
# date book added: Mon Mar 26 03:27:17 -0700 2018
# book was not added in 2019
#
# Technopoly: The Surrender of Culture to Technology
# date book added: Fri Mar 23 04:52:10 -0700 2018
# book was not added in 2019
#
# Understanding Power: The Indispensable Chomsky
# date book added: Sun Mar 11 08:48:13 -0700 2018
# book was not added in 2019
#
# The Signal and the Noise: Why So Many Predictions Fail - But Some Don't
# date book added: Tue Mar 06 21:55:59 -0800 2018
# book was not added in 2019
#
# The Road to Reality: A Complete Guide to the Laws of the Universe
# date book added: Thu Mar 01 19:36:21 -0800 2018
# book was not added in 2019
#
# The Path: What Chinese Philosophers Can Teach Us About the Good Life
# date book added: Wed Feb 28 06:49:49 -0800 2018
# book was not added in 2019
#
# Thinking, Fast and Slow
# date book added: Wed Feb 28 04:16:22 -0800 2018
# book was not added in 2019
#
# Factfulness: Ten Reasons We're Wrong About the World--and Why Things Are Better Than You Think
# date book added: Tue Feb 27 21:34:45 -0800 2018
# book was not added in 2019
#
# The Waste Land and Other Poems
# date book added: Wed Feb 21 08:05:45 -0800 2018
# book was not added in 2019
#
# The Stand
# date book added: Wed Feb 21 08:04:03 -0800 2018
# book was not added in 2019
#
# American Gods (American Gods, #1)
# date book added: Wed Feb 21 07:52:44 -0800 2018
# book was not added in 2019
#
# The House of Silk (Sherlock Holmes, #1)
# date book added: Wed Feb 21 07:49:54 -0800 2018
# book was not added in 2019
#
# Magpie Murders
# date book added: Wed Feb 21 07:49:49 -0800 2018
# book was not added in 2019
#
# Thinking With Type
# date book added: Wed Feb 21 06:18:07 -0800 2018
# book was not added in 2019
#
# Super Normal: Sensations of the Ordinary
# date book added: Wed Feb 21 06:14:28 -0800 2018
# book was not added in 2019
#
# Why I Write
# date book added: Wed Feb 21 06:13:02 -0800 2018
# book was not added in 2019
#
# Not so too much of much of everything
# date book added: Wed Feb 21 06:12:41 -0800 2018
# book was not added in 2019
#
# Kengo Kuma: Small Architecture / Natural Architecture
# date book added: Wed Feb 21 06:11:55 -0800 2018
# book was not added in 2019
#
# Fire and Fury: Inside the Trump White House
# date book added: Wed Feb 21 05:52:14 -0800 2018
# book was not added in 2019
#
# Alex Ferguson: My Autobiography
# date book added: Wed Feb 21 05:48:44 -0800 2018
# book was not added in 2019
#
# The Vatican to Vegas: A History of Special Effects
# date book added: Wed Jan 24 05:44:27 -0800 2018
# book was not added in 2019
#
# Flatland: A Romance of Many Dimensions
# date book added: Wed Jan 24 05:44:04 -0800 2018
# book was not added in 2019
#
# Paint by Numbers: A Charles Bloom Murder Mystery (1st in series)
# date book added: Wed Jan 24 05:43:47 -0800 2018
# book was not added in 2019
#
# Future Noir: The Making of Blade Runner
# date book added: Sun Jan 07 08:50:41 -0800 2018
# book was not added in 2019
#
# Retrofitting Blade Runner: Issues in Ridley Scott's Blade Runner and Philip K. Dick's Do Androids Dream of Electric Sheep?
# date book added: Sun Jan 07 08:49:37 -0800 2018
# book was not added in 2019
#
# Living with Complexity
# date book added: Wed Dec 27 22:40:54 -0800 2017
# book was not added in 2019
#
# Emotional Design: Why We Love (or Hate) Everyday Things
# date book added: Wed Dec 27 22:40:53 -0800 2017
# book was not added in 2019
#
# A Burglar's Guide to the City
# date book added: Wed Dec 27 09:52:27 -0800 2017
# book was not added in 2019
#
# The Shape of the Final Dog
# date book added: Wed Dec 20 08:12:48 -0800 2017
# book was not added in 2019
#
# Blood Meridian, or the Evening Redness in the West
# date book added: Tue Nov 28 07:23:04 -0800 2017
# book was not added in 2019
#
# The Human Predicament: A Candid Guide to Life's Biggest Questions
# date book added: Mon Nov 27 06:14:17 -0800 2017
# book was not added in 2019
#
# The Pale King
# date book added: Sun Nov 12 06:52:24 -0800 2017
# book was not added in 2019
#
# Infinite Jest
# date book added: Sun Nov 12 06:50:29 -0800 2017
# book was not added in 2019
#
# Lynch on Lynch
# date book added: Fri Nov 10 08:56:00 -0800 2017
# book was not added in 2019
#
# A Thousand Years of Nonlinear History
# date book added: Sat Nov 04 07:47:56 -0700 2017
# book was not added in 2019
#
# The Mixer: The Story of Premier League Tactics, from Route One to False Nines
# date book added: Sat Nov 04 06:58:42 -0700 2017
# book was not added in 2019
#
# The Myth of Sisyphus and Other Essays
# date book added: Thu Nov 02 11:41:34 -0700 2017
# book was not added in 2019
#
# Ways of Seeing
# date book added: Sun Oct 29 10:02:28 -0700 2017
# book was not added in 2019
#
# A Woman Looking at Men Looking at Women: Essays on Art, Sex, and the Mind
# date book added: Sun Oct 29 10:01:11 -0700 2017
# book was not added in 2019
#
# The Invention of Morel
# date book added: Wed Oct 25 04:52:23 -0700 2017
# book was not added in 2019
#
# The Remains of the Day
# date book added: Tue Oct 24 05:02:38 -0700 2017
# book was not added in 2019
#
# Non-Places: Introduction to an Anthropology of Supermodernity
# date book added: Tue Oct 03 05:25:46 -0700 2017
# book was not added in 2019
#
# Crime and Punishment
# date book added: Thu Sep 21 22:46:06 -0700 2017
# book was not added in 2019
#
# In Contempt
# date book added: Sun Jul 23 02:31:47 -0700 2017
# book was not added in 2019
#
# Weapons of Math Destruction: How Big Data Increases Inequality and Threatens Democracy
# date book added: Sat Jul 15 06:16:51 -0700 2017
# book was not added in 2019
#
# Whiplash: How to Survive Our Faster Future
# date book added: Sat Jul 15 05:58:50 -0700 2017
# book was not added in 2019
#
# The Deep End (The Country Club Murders #1)
# date book added: Tue Jun 13 07:52:43 -0700 2017
# book was not added in 2019
#
# The Gene: An Intimate History
# date book added: Sat Jan 07 21:08:35 -0800 2017
# book was not added in 2019
#
# Steppenwolf
# date book added: Wed Jan 04 07:53:39 -0800 2017
# book was not added in 2019
#
# Stories of Your Life and Others
# date book added: Mon Nov 14 10:03:07 -0800 2016
# book was not added in 2019
#
# Underground: The Tokyo Gas Attack and the Japanese Psyche
# date book added: Fri Sep 16 09:22:44 -0700 2016
# book was not added in 2019
#
# The Design of Everyday Things
# date book added: Sat Aug 27 10:44:07 -0700 2016
# book was not added in 2019
#
# Death by Video Game: Tales of Obsession from the Virtual Frontline
# date book added: Sat Aug 27 10:43:42 -0700 2016
# book was not added in 2019
#
# Fear and Loathing in Las Vegas
# date book added: Sat Aug 27 10:43:00 -0700 2016
# book was not added in 2019
#
# Revolutionary Road
# date book added: Sat Aug 27 10:42:04 -0700 2016
# book was not added in 2019
#
# The Philosophy of Andy Warhol
# date book added: Sat Aug 27 10:41:23 -0700 2016
# book was not added in 2019
#
# Fates and Furies
# date book added: Tue Feb 09 00:59:13 -0800 2016
# book was not added in 2019
#
# 1984
# date book added: Tue Feb 09 00:59:09 -0800 2016
# book was not added in 2019

# %%
len(to_read_2019)
# Out:
# 100

# %%
to_read_2019[5]
# Out:
# OrderedDict([('id', '3071181980'),
#              ('book',
#               OrderedDict([('id',
#                             OrderedDict([('@type', 'integer'),
#                                          ('#text', '23374497')])),
#                            ('isbn', '1608464458'),
#                            ('isbn13', '9781608464456'),
#                            ('text_reviews_count',
#                             OrderedDict([('@type', 'integer'),
#                                          ('#text', '1')])),
#                            ('uri',
#                             'kca://book/amzn1.gr.book.v1.IUXvJ0SYj2hi_PdSZIxi7Q'),
#                            ('title',
#                             'Rethinking Camelot: Jfk, the Vietnam War, and U.S. Political Culture'),
#                            ('title_without_series',
#                             'Rethinking Camelot: Jfk, the Vietnam War, and U.S. Political Culture'),
#                            ('image_url',
#                             'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1416445885l/23374497._SX98_.jpg'),
#                            ('small_image_url',
#                             'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1416445885l/23374497._SX50_.jpg'),
#                            ('large_image_url', None),
#                            ('link',
#                             'https://www.goodreads.com/book/show/23374497-rethinking-camelot'),
#                            ('num_pages', '172'),
#                            ('format', 'ebook'),
#                            ('edition_information', None),
#                            ('publisher', 'Haymarket Books'),
#                            ('publication_day', '30'),
#                            ('publication_year', '2015'),
#                            ('publication_month', '3'),
#                            ('average_rating', '3.77'),
#                            ('ratings_count', '172'),
#                            ('description',
#                             'Nom Chomsky dismisses efforts to resurrect Camelot--an attractive American myth portraying JFK as a shinning knight promising peace, foiled only by assassins bent on stopping this lone hero from withdrawing from Vietnam. Chomsky argues that US institutions an political culture, not individual presidents, are the key to understanding US behavior during the Vietnam War.'),
#                            ('authors',
#                             OrderedDict([('author',
#                                           OrderedDict([('id', '2476'),
#                                                        ('name',
#                                                         'Noam Chomsky'),
#                                                        ('role', None),
#                                                        ('image_url',
#                                                         OrderedDict([('@nophoto',
#                                                                       'false'),
#                                                                      ('#text',
#                                                                       'https://images.gr-assets.com/authors/1485473965p5/2476.jpg')])),
#                                                        ('small_image_url',
#                                                         OrderedDict([('@nophoto',
#                                                                       'false'),
#                                                                      ('#text',
#                                                                       'https://images.gr-assets.com/authors/1485473965p2/2476.jpg')])),
#                                                        ('link',
#                                                         'https://www.goodreads.com/author/show/2476.Noam_Chomsky'),
#                                                        ('average_rating',
#                                                         '4.03'),
#                                                        ('ratings_count',
#                                                         '115768'),
#                                                        ('text_reviews_count',
#                                                         '7587')]))])),
#                            ('published', '2015'),
#                            ('work',
#                             OrderedDict([('id', '932235'),
#                                          ('uri',
#                                           'kca://work/amzn1.gr.work.v1.yk0LbLAiIsJ69YOqJsX8kQ')]))])),
#              ('rating', '0'),
#              ('votes', '0'),
#              ('spoiler_flag', 'false'),
#              ('spoilers_state', 'none'),
#              ('shelves',
#               OrderedDict([('shelf',
#                             OrderedDict([('@exclusive', 'true'),
#                                          ('@id', '171366659'),
#                                          ('@name', 'to-read'),
#                                          ('@review_shelf_id', '2718665546'),
#                                          ('@sortable', 'true')]))])),
#              ('recommended_for', None),
#              ('recommended_by', None),
#              ('started_at', None),
#              ('read_at', None),
#              ('date_added', 'Tue Dec 03 07:44:47 -0800 2019'),
#              ('date_updated', 'Tue Dec 03 07:44:47 -0800 2019'),
#              ('read_count', '0'),
#              ('body', None),
#              ('comments_count', '0'),
#              ('url', 'https://www.goodreads.com/review/show/3071181980'),
#              ('link', 'https://www.goodreads.com/review/show/3071181980'),
#              ('owned', '0')])

# %%
date_occurances = []
for boo in to_read_2019:
    date_occurances.append(boo['date_added'][:10])

# %%
len(date_occurances)
# Out:
# 100

# %%
len(set(date_occurances))
# Out:
# 70

# %%
occ = Counter(date_occurances)

# %%
plt.rcParams["figure.figsize"] = (100,10)

# %%
plt.bar(occ.keys(), occ.values())
# Out:
# <BarContainer object of 70 artists>

# %%
# dates are un-ordered so attempt to takke a shortcut and strip characters instead of converting date string to a date object has failed!!
